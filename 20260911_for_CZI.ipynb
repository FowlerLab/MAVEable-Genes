# %%
import pandas as pd

# %%
maaveable_df = pd.read_csv('MAVEable_final_is_feasible.csv')
maaveable_df.head()
# Out:
#    Unnamed: 0 GeneSymbol  #AlleleID  GeneID     HGNC_ID  \
# 0           0       AAAS      20083    8086  HGNC:13666
# 1           1      AAGAB     703299   79719  HGNC:25662
# 2           2      AARS1      23505      16     HGNC:20
# 3           3      AARS2      39897   57505  HGNC:21022
# 4           4       AASS     247012   10157  HGNC:17366
#
#                                         PhenotypeIDS  \
# 0  MONDO:MONDO:0009279,MedGen:C0271742,OMIM:23155...
# 1                                    MedGen:C3661900
# 2  MONDO:MONDO:0013212,MedGen:C2750090,OMIM:61328...
# 3  MONDO:MONDO:0013570,MedGen:C4518839,OMIM:61409...
# 4  MedGen:CN169374|Human Phenotype Ontology:HP:00...
#
#                                        PhenotypeList  \
# 0  Glucocorticoid deficiency with achalasia|not p...
# 1                                       not provided
# 2  Charcot-Marie-Tooth disease axonal type 2N|Cha...
# 3  Combined oxidative phosphorylation defect type...
# ...

# %%
maaveable_df = maaveable_df[maaveable_df['Length'] < 592]
maaveable_df.shape

# %%
maaveable_df.to_csv('MAVEable_filtered_length_lt592.csv', index=False)
